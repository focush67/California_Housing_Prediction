# %% [markdown]
# # Importing the Standard Libraries Required

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
dataFrame = pd.read_csv("housing.csv")

# %%
# DataFrame loaded , just checking the look of it

# %%
dataFrame.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
dataFrame.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# Checking for correlations to eliminate repetitive features or unncecessary ones

# %%
dataFrame.corr(method='pearson')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19188\3277519863.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataFrame.corr(method='pearson')
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# ...

# %%
# total_bedrooms feature is very highly correlated to household and also contains null values

# %%
dataFrame.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
dataFrame.corr()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19188\3497904997.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataFrame.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# ...

# %%
# Exploratory Data Analysis to find useful insights

# %%
plt.scatter(dataFrame['longitude'] , dataFrame['median_house_value'])
plt.xlabel('longitude')
plt.ylabel('median_house_value')
# Out:
# Text(0, 0.5, 'median_house_value')

# %%
plt.scatter(dataFrame['housing_median_age'] , dataFrame['median_house_value'])
plt.xlabel('housing_median_age')
plt.ylabel('median_house_value')
# Out:
# Text(0, 0.5, 'median_house_value')

# %%
plt.scatter(dataFrame['total_rooms'] , dataFrame['median_house_value'])
plt.xlabel('total_rooms')
plt.ylabel('median_house_value')
# Out:
# Text(0, 0.5, 'median_house_value')

# %%
plt.scatter(dataFrame['population'] , dataFrame['median_house_value'])
plt.xlabel('population')
plt.ylabel('median_house_value')
# Out:
# Text(0, 0.5, 'median_house_value')

# %%
plt.scatter(dataFrame['households'] , dataFrame['median_house_value'])
plt.xlabel('households')
plt.ylabel('median_house_value')
# Out:
# Text(0, 0.5, 'median_house_value')

# %%
plt.scatter(dataFrame['median_income'] , dataFrame['median_house_value'])
plt.xlabel('median_income')
plt.ylabel('median_house_value')
# Out:
# Text(0, 0.5, 'median_house_value')

# %%
plt.scatter(dataFrame['ocean_proximity'] , dataFrame['median_house_value'])
plt.xlabel('ocean_proximity')
plt.ylabel('median_house_value')
# Out:
# Text(0, 0.5, 'median_house_value')

# %%
sns.regplot(x = "median_income" , y = "median_house_value" , data = dataFrame)
# Out:
# <AxesSubplot: xlabel='median_income', ylabel='median_house_value'>

# %%
sns.histplot(data = dataFrame , x = "median_house_value" , kde = True)
# Out:
# <AxesSubplot: xlabel='median_house_value', ylabel='Count'>

# %%
sns.histplot(data = dataFrame , x = "latitude" , kde = True)
# Out:
# <AxesSubplot: xlabel='latitude', ylabel='Count'>

# %%
# From analysing above 2 histogram plots and other scatter polts before , It is clear that the data is not normally distributed.
